# %%
# Celda 1
import pandas as pd
from importlib import import_module
import sys; sys.path.append('.')
from conexion_datos import cargar_margen_por_venta

df = cargar_margen_por_venta()
df.head()
# Out:
#    id_venta fecha_venta nombre_sucursal        ciudad      region  \
# 0         1  2024-09-25   Sucursal Este  Viña del Mar  Valparaíso
# 1         2  2024-07-12    Sucursal Sur    Concepción         Sur
# 2         3  2024-12-02  Sucursal Norte      Santiago      Centro
# 3         4  2024-05-04    Sucursal Sur    Concepción         Sur
# 4         5  2024-08-30    Sucursal Sur    Concepción         Sur
#
#   nombre_producto    categoria  cantidad_vendida  precio_venta  \
# 0          Laptop  Electrónica                 2        1200.0
# 1     Auriculares   Accesorios                 7          70.0
# 2          Laptop  Electrónica                 6        1200.0
# 3     Auriculares   Accesorios                 7          70.0
# 4          Tablet  Electrónica                 2         500.0
#
#    costo_unitario  total_venta  margen_total  margen_pct
# 0           800.0       2400.0         800.0        33.3
# 1            40.0        490.0         210.0        42.9
# ...

# %%
# Celda 2 — panorama general
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1105 entries, 0 to 1104
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_venta          1105 non-null   int64
#  1   fecha_venta       1105 non-null   object
#  2   nombre_sucursal   1105 non-null   str
#  3   ciudad            1105 non-null   str
#  4   region            1105 non-null   str
#  5   nombre_producto   1105 non-null   str
#  6   categoria         1105 non-null   str
#  7   cantidad_vendida  1105 non-null   int64
#  8   precio_venta      1105 non-null   float64
#  9   costo_unitario    1105 non-null   float64
#  10  total_venta       1105 non-null   float64
#  11  margen_total      1105 non-null   float64
#  12  margen_pct        1105 non-null   float64
# dtypes: float64(5), int64(2), object(1), str(5)
# memory usage: 165.7+ KB
#            id_venta fecha_venta nombre_sucursal        ciudad      region  \
# ...

# %%
# Celda 3 — validación de calidad (ya la hiciste en SQL, aquí la confirmas en Python)
print("Nulos por columna:\n", df.isnull().sum())
print("\nFilas duplicadas exactas:", df.duplicated().sum())
print("\nRango de fechas:", df['fecha_venta'].min(), "-", df['fecha_venta'].max())
# Out:
# Nulos por columna:
#  id_venta            0
# fecha_venta         0
# nombre_sucursal     0
# ciudad              0
# region              0
# nombre_producto     0
# categoria           0
# cantidad_vendida    0
# precio_venta        0
# costo_unitario      0
# total_venta         0
# margen_total        0
# margen_pct          0
# dtype: int64
#
# Filas duplicadas exactas: 0
#
# Rango de fechas: 2024-03-01 - 2025-02-28

# %%
# Celda 4 — margen agregado por dimensión (cruce con lo que ya calculaste en SQL)
df.groupby('nombre_producto')['margen_total'].sum().sort_values(ascending=False)
# Out:
# nombre_producto
# Laptop         382800.0
# Smartphone     220200.0
# Tablet         156600.0
# Monitor         86400.0
# Impresora       49200.0
# Auriculares     25200.0
# Teclado         25050.0
# Mouse           11445.0
# Name: margen_total, dtype: float64

# %%
df.groupby('nombre_sucursal')['margen_total'].sum().sort_values(ascending=False)
# Out:
# nombre_sucursal
# Sucursal Este     278750.0
# Sucursal Sur      240545.0
# Sucursal Oeste    218910.0
# Sucursal Norte    218690.0
# Name: margen_total, dtype: float64
